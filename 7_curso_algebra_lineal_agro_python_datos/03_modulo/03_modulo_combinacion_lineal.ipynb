# %% [markdown]
# ### [Evaluamos el servicio de enseñanza del profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/linear_algebra/blob/main/7_curso_algebra_lineal_agro_python_datos/03_modulo/03_modulo_combinacion_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/linear_algebra/blob/main/7_curso_algebra_lineal_agro_python_datos/03_modulo/03_modulo_combinacion_lineal.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %%
# QR para el cuaderno de clase que permite lectura activa y experimental
import qrcode
from PIL import Image
import os

# URL del notebook en GitHub
url = "https://colab.research.google.com/github/marco-canas/linear_algebra/blob/main/7_curso_algebra_lineal_agro_python_datos/03_modulo/03_modulo_combinacion_lineal.ipynb"

# Configuración del QR
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_H,
    box_size=4,
    border=4,
)

# Añadir datos al QR
qr.add_data(url)
qr.make(fit=True)

# Crear imagen del QR
img = qr.make_image(fill_color="black", back_color="white")

# Guardar imagen
output_path = "github_notebook_qr.png"
img.save(output_path)

# Mostrar imagen generada (solo si se ejecuta en Jupyter Notebook/Lab)
try:
    display(Image.open(output_path))
except:
    print(f"Código QR generado y guardado en: {os.path.abspath(output_path)}")
    print("Ábralo con cualquier visor de imágenes o escanéelo con su móvil.")
    img.show()  # Abre la imagen en el visor predeterminado
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=292x292>

# %% [markdown]
# ### [Video de apoyo a la lectura al libro de Clara Elena en cuanto al módulo 3]()

# %% [markdown]
# ### [Video de apoyo a la presentación manuscrita del módulo 3 Sobre Combinación Lineal]()

# %% [markdown]
# ### [Video de apoyo a la presentación del módulo 3 sobre Combinación lineal, generadores y espacio generado con Python](https://www.youtube.com/watch?v=2L-G3YiVb9g)

# %% [markdown]
# ### [Vínculo al programa del curso: Linear_Algebra ](https://github.com/marco-canas/linear_algebra/blob/main/3_clases_segun_clara_mejia_laverde/0_programa_cronograma_curso/1_programa_linear_algebra/1_programa_linear_algebra.md)
#
# Código del curso: 5009329

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = 'https://github.com/marco-canas/linear_algebra/blob/main/6_images/geo_vectorial_ultima_clase_2025-11-04.jpg?raw=true' width = 400>

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde el archivo CSV
path = 'C:/Users/marco/Documentos/docencia/groups_list/linear_algebra.xlsx'
df = pd.read_excel(path)
df.index = range(1, len(df) + 1)
df.head(11)
# Out:
#         Cédula                           Nombre  \
# 1   1007676529    ARENAS HERAZO GABRIEL ENRIQUE
# 2   1038547924  ARROYAVE ECHAVARRIA LAURA SOFIA
# 3   1007528664     AYALA MENDOZA MARISOL YACIRA
# 4   1007676170          CANTILLO ENSUCHO DANIEL
# 5   1038104030     IBAÑEZ MORENO FRANCISCO LUIS
# 6   1066570075            MONTERROSA SOTO ABRIL
# 7   1038099623         NORIEGA JIMENEZ GABRIELA
# 8   1129805618             PEREZ THERAN ERLINDA
# 9   1038101968       QUINONEZ CERVANTES MARIANA
# 10  1007318378               RAMOS PEREZ YANINE
# 11  1001548515          VARGAS SALINAS LEONARDO
#
#                             Email   p1   p2
# 1      gabriel.arenas@udea.edu.co  0.0  NaN
# 2      sofia.arroyave@udea.edu.co  0.0  NaN
# 3       marisol.ayala@udea.edu.co  0.1  0.2
# 4     daniel.cantillo@udea.edu.co  0.1  3.2
# 5    francisco.ibanez@udea.edu.co  0.0  4.0
# 6        a.monterrosa@udea.edu.co  0.1  0.1
# 7    gabriela.noriega@udea.edu.co  0.1  0.7
# ...

# %% [markdown]
# # Principios de mi labor docente

# %% [markdown]
# ### Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# <img src = 'https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png' width = 100>

# %% [markdown]
# ### Metodología de Aprendizaje Basado en Problemas y Proyectos (ABPP)

# %% [markdown]
# <img src = 'https://www.unir.net/wp-content/uploads/2020/07/aprendizaje-problemas2-1-1-1-1.jpeg' width = 100>

# %% [markdown]
# ### Desarrollo del pensamiento computacional con Lenguajes Python y R, y con archivos Markdown orientado a la formación en ciencia de datos

# %% [markdown]
# <img src = 'https://i.ytimg.com/vi/mcG_wcR4e6M/maxresdefault.jpg' width = 100>

# %% [markdown]
# ### Principio de fomento a la ciencia abierta, enseñar en el acceso a los datos públicos y el uso de software de código abierto

# %% [markdown]
# <img src = 'https://unesdoc.unesco.org/in/rest/Thumb/image?id=p%3A%3Ausmarcdef_0000379949_spa&author=UNESCO&title=Recomendaci%C3%B3n+de+la+UNESCO+sobre+la+Ciencia+Abierta&year=2021&publisher=UNESCO&TypeOfDocument=UnescoPhysicalDocument&mat=PGD&ct=true&size=512&isPhysical=1' width = 100>

# %% [markdown]
# El enfoque STEAMS en educación preescolar, primaria y secundaria es una extensión del enfoque STEM (Ciencia, Tecnología, Ingeniería y Matemáticas) y su variante STEAM, que incorpora el Arte.

# %% [markdown]
# <img src = 'https://www.campuseducacion.com/blog/wp-content/uploads/2023/03/foto01-1.jpg' width = 100>

# %% [markdown]
# ### Y el enfoque de Teoría de Registros de Representación Semiótica de Duval

# %% [markdown]
# # Módulo 3. Combinación lineal, conjuntos finitos generadores y espacios generados

# %% [markdown]
# # Clase sobre: "Combinación lineal, conjuntos finitos generadores y espacios generados", en el contexto de ingeniería agropecuaria y Administración de empresas emulando la estructura de clase de Clara Mejía Laverde y utilizando los Lenguaje Python y Latex; y las redes sociales GitHub y YouTube con orientación a la ciencia de datos con Técnicas de Machine Learning y Deep Learning.
#
# # Estructura de cada Módulo (Total de módulos: 22)
#
# 1. Título
# 2. Imagen introductoria generado con Plotly
# 3. Describe el Contenido de este módulo.
# 4. Objetivos de aprendizaje
# 5. Preguntas Orientadoras
# 6. Introducción
# 7. Dos situaciones problemáticas asociadas a ciencia de datos agropecuarios o de Administración de Empresas y al tema del módulo en particular (Para el módulo 3: debes dar una situación donde se aplique el tema de: Combinación lineal, conjuntos finitos generadores y espacios generados). Por ejemplo, datos asociados a mediciones en agricultura de precisión.
# 8. Genere, de manera artificial, los dos datasets asociados la situción problemática anterior.
# 9.  Definiciones asociadas al módulo respectivo (Para este cuaderno el módulo 3: debes dar las definiciones en lenguaje Látex asociadas al tema de: "Combinación lineal, conjuntos finitos generadores y espacios generados")
# 10. Ejemplos: (Genere ejemplos de aplicación de estos conceptos de este módulo a las dos situaciones anteriores)
# 11. Teoremas: (Genere los teoremas del álgebra lineal que facilitan el uso de los temas del módulo para la solución de la situación problemática.)
# 12. Ejemplos: (Genere ejemplos de aplicación de los teoremas para los datasets de las situaciones problemáticas del módulo)
# 13. Dame la solución a las dos situaciones problemáticas del item 7 con los datos artificiales generados en el item 8 de este diseño.
# 14. Ejercicios (Genere ejercicios sugeridos con datasets artificiales nuevos)
# 15. Referentes Didácticos y del Álgebra Lineal que sustenten y apoyan esta propuesta de enseñanza.

# %% [markdown]
# Para iniciar este ambicioso proyecto de 22 módulos, el título debe capturar la esencia del álgebra lineal aplicada, la visión técnica de la ciencia de datos y el contexto específico de la ingeniería y la administración.

# %% [markdown]
# Siguiendo el estilo de **Clara Mejía Laverde**, donde se prioriza la claridad pedagógica y la aplicabilidad práctica, aquí tienes el diseño de la **Etapa 1: Título**.
#
# ---

# %% [markdown]
# ## 1. Título del Módulo 3
#
# # Álgebra de la Productividad: Combinaciones Lineales y Espacios Generados en la Optimización Agroempresarial con Python
#
# ### Subtítulo Curricular:
# > **"De la abstracción vectorial a la Ciencia de Datos: Modelado de recursos, conjuntos generadores y bases fundamentales para el aprendizaje profundo en Ingeniería Agropecuaria y Administración de Empresas."**
#
# ---

# %% [markdown]
# ### Notas de diseño del título:
#
# * **Enfoque en Ingeniería Agropecuaria:** El término "Productividad" resuena con el rendimiento de cultivos y la eficiencia de recursos (agua, fertilizantes, semillas).
# * **Enfoque en Administración:** La "Optimización" es el núcleo de la toma de decisiones financieras y logísticas.
# * **Componente Tecnológico:** Se menciona explícitamente **Python**, estableciendo la expectativa de que los conceptos matemáticos se traducirán en código ejecutable, tal como se propone en el uso de GitHub y YouTube.
# * **Nivel de Profundidad:** Al mencionar "Aprendizaje Profundo" (Deep Learning), el título vincula la **combinación lineal** (que es, en esencia, lo que ocurre dentro de una neurona artificial como $z = \sum w_i x_i + b$) con el tema central del módulo.

# %% [markdown]
# Siguiendo la estructura pedagógica de Clara Mejía Laverde, esta imagen no debe ser solo decorativa; debe ser una **herramienta visual** que capture la esencia matemática y aplicada del módulo.

# %% [markdown]
# # Conceptualización de la Imagen para el Módulo 3:

# %% [markdown]
# Visualizaremos la **Combinación Lineal** y el **Espacio Generado** en un contexto tridimensional que representa insumos agrícolas (ej. Nitrógeno y Fósforo) y un resultado productivo (ej. Rendimiento de Cultivo).

# %% [markdown]
# 1.  **Vectores Base (Conjunto Generador):** Mostraremos dos vectores ($\mathbf{v_1}$ y $\mathbf{v_2}$) en el piso ($z = 0$), representando "Recetas Estándar" de fertilizante.
# 2.  **Combinación Lineal:** Crearemos un nuevo vector ($\mathbf{y}$) que es la suma escalada de los dos primeros.
# 3.  **Espacio Generado ($Span$):** Dibujaremos un plano translúcido que pasa por el origen y contiene a los dos vectores base. Este plano representa *todas* las posibles combinaciones de fertilizantes y sus rendimientos potenciales.

# %% [markdown]
# Este concepto es fundamental para Machine Learning (ej. Regresión Lineal Multiple), donde buscamos predecir un resultado ($y$) como una combinación lineal de características ($x_i$).

# %% [markdown]
# ### Código Python con Plotly para la Imagen Introductoria

# %%
import plotly.graph_objects as go
import numpy as np

# 1. Definición de Vectores Base (Insumos/Características)
# Supongamos: v1 = [Nitrógeno=2, Fósforo=1, RendimientoBase=0]
#            v2 = [Nitrógeno=1, Fósforo=3, RendimientoBase=0]
# El rendimiento base es 0 para que vivan en el "piso" R2 primero.
v1 = np.array([2, 1, 0])
v2 = np.array([1, 3, 0])

# 2. Definición de Escalares (Decisión de Administración)
c1 = 1.5
c2 = 2.0

# 3. Cálculo de la Combinación Lineal (Resultado Productivo)
# y = c1*v1 + c2*v2
# y = 1.5*[2,1,0] + 2.0*[1,3,0] = [3,1.5,0] + [2,6,0] = [5, 7.5, 0]
y = c1 * v1 + c2 * v2

# 4. Generación del Plano (Espacio Generado - Span)
# Creamos una malla de escalares para visualizar el plano generado por v1 y v2
s = np.linspace(-1, 4, 10)
t = np.linspace(-1, 4, 10)
S, T = np.meshgrid(s, t)

# El plano es S*v1 + T*v2
plane_x = S * v1[0] + T * v2[0]
plane_y = S * v1[1] + T * v2[1]
plane_z = S * v1[2] + T * v2[2] # En este caso simple, z será siempre 0.

# 5. Creación de la Figura Plotly
fig = go.Figure()

# -- A. Dibujar el Espacio Generado (Plano translúcido) --
fig.add_trace(go.Surface(x=plane_x, y=plane_y, z=plane_z,
                         colorscale='Greens', opacity=0.3,
                         showscale=False, name='Espacio Generado (Span)'))

# -- B. Dibujar Vectores Base (Conjunto Generador) --
# Vector 1
fig.add_trace(go.Scatter3d(x=[0, v1[0]], y=[0, v1[1]], z=[0, v1[2]],
                           mode='lines+markers+text',
                           line=dict(color='blue', width=6),
                           marker=dict(size=4),
                           text=["", "<b>v₁</b> (Insumo A)"], textposition="top center",
                           name='Vector Generador v₁'))
# Vector 2
fig.add_trace(go.Scatter3d(x=[0, v2[0]], y=[0, v2[1]], z=[0, v2[2]],
                           mode='lines+markers+text',
                           line=dict(color='blue', width=6),
                           marker=dict(size=4),
                           text=["", "<b>v₂</b> (Insumo B)"], textposition="top center",
                           name='Vector Generador v₂'))

# -- C. Dibujar la Combinación Lineal (Resultado) --
fig.add_trace(go.Scatter3d(x=[0, y[0]], y=[0, y[1]], z=[0, y[2]],
                           mode='lines+markers+text',
                           line=dict(color='red', width=8, dash='dash'),
                           marker=dict(size=6, symbol='diamond'),
                           text=["", f"<b>y</b> = {c1}v₁ + {c2}v₂<br>(Resultado)"],
                           textposition="bottom right",
                           name='Combinación Lineal y'))

# 6. Configuración del Diseño (Layout) - Estilo Profesional
fig.update_layout(
    title=dict(
        text="Visualización de Combinación Lineal y Espacio Generado<br>"
             "<sup>Contexto: Optimización de Insumos Agropecuarios (v₁, v₂) para obtener un Resultado (y)</sup>",
        x=0.5, y=0.95
    ),
    scene=dict(
        xaxis_title='Característica 1 (ej. Nitrógeno)',
        yaxis_title='Característica 2 (ej. Fósforo)',
        zaxis_title='Eje Algebraico (z=0)',
        camera=dict(eye=dict(x=1.5, y=1.5, z=0.8)) # Perspectiva inicial
    ),
    margin=dict(l=0, r=0, b=0, t=60),
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01),
    template="plotly_white"
)

# 7. Mostrar la imagen (En un Jupyter Notebook)
fig.show()
fig.write_image(r"C:\Users\marco\Downloads\módulo3_combinacion_lineal.png", scale=2)  # Para exportar como imagen de alta calidad

# Para exportar como HTML estático (para GitHub pages o YouTube descripciones):
# fig.write_html("módulo3_combinacion_lineal.html")

# %% [markdown]
# # Descripción de la Imagen (Para el Cuaderno):
#
# "Esta visualización interactiva de Plotly ilustra cómo dos vectores base, $\mathbf{v_1}$ y $\mathbf{v_2}$ (en azul), que representan estrategias de insumos estándar, **generan** un plano entero (en verde translúcido).

# %% [markdown]
# Cualquier punto dentro de ese plano es una **combinación lineal** de los vectores base. El vector rojo $\mathbf{y}$ representa una decisión específica de administración: aplicar $1.5$ veces la estrategia $\mathbf{v_1}$ y $2.0$ veces la $\mathbf{v_2}$. En el contexto de Machine Learning, el plano verde representa el espacio de soluciones posibles que nuestro modelo lineal puede predecir."

# %% [markdown]
# Continuando con la estructura pedagógica inspirada en la metodología de **Clara Mejía Laverde**, procedemos con el desarrollo de los componentes 3, 4 y 5. Esta sección establece el puente entre la teoría abstracta y la aplicación práctica en la toma de decisiones basada en datos.
#
# ---

# %% [markdown]
# ## 3. Contenido del Módulo
#
# Este módulo se centra en desglosar la estructura fundamental de los espacios vectoriales a través del concepto de **dependencia y generación**. En la administración de empresas y la ingeniería agropecuaria, los datos no son valores aislados; son vectores que representan perfiles de suelo, costos de producción o variables climáticas.
#
# **Los temas a tratar son:**
# * **Combinación Lineal:** La suma ponderada de vectores como modelo de mezcla de recursos.
# * **Sistemas de Ecuaciones Lineales:** Su interpretación como la búsqueda de escalares para alcanzar un objetivo específico.
# * **Conjuntos Finitos Generadores:** Identificación de las variables mínimas necesarias para describir un fenómeno productivo.
# * **Espacio Generado ($Span$):** El universo de todas las posibilidades alcanzables dadas las restricciones de recursos o datos disponibles.
# * **Aplicación en Data Science:** Cómo estas estructuras forman la base de la **Regresión Lineal** y la reducción de dimensionalidad en **Machine Learning**.
#
# ---

# %% [markdown]
# ## 4. Objetivos de Aprendizaje
#
# Al finalizar este módulo, el estudiante estará en capacidad de:
#
# 1.  **Analizar** matemáticamente si un vector de resultados (ej. rendimiento de cosecha o meta de ventas) puede obtenerse mediante una **combinación lineal** de un conjunto de vectores de insumos.
# 2.  **Determinar** el **espacio generado** por un conjunto de datos agroindustriales para identificar los límites de un modelo predictivo.
# 3.  **Implementar** algoritmos en **Python** (usando `NumPy` y `SciPy`) para resolver sistemas de combinaciones lineales en contextos de mezclas óptimas.
# 4.  **Vincular** el concepto de combinación lineal con la arquitectura de una **Neurona Artificial**, comprendiendo cómo los pesos ($w$) y las entradas ($x$) operan en un espacio vectorial.
#
# ---

# %% [markdown]
# ## 5. Preguntas Orientadoras
#
# Para fomentar el pensamiento crítico y la curiosidad científica, este módulo se abordará desde las siguientes interrogantes:
#
# * **Desde la Ingeniería:** Si tengo tres tipos de fertilizantes con diferentes concentraciones de N-P-K, ¿existe alguna combinación de ellos que me permita alcanzar exactamente los requerimientos nutricionales de un cultivo de palma de aceite?
# * **Desde la Administración:** ¿Es posible expresar el portafolio de inversión de una empresa como una suma escalada de activos básicos, o existen "dimensiones" de riesgo que no estamos cubriendo?
# * **Desde la Ciencia de Datos:** ¿Por qué decimos que una red neuronal profunda es, en sus capas iniciales, una sucesión de combinaciones lineales y qué sucede cuando un dato de prueba cae fuera del *espacio generado* por los datos de entrenamiento?
# * **Desde la Computación:** ¿Cómo podemos usar la eliminación gaussiana en Python para validar si un conjunto de vectores es un sistema generador eficiente o si presenta redundancias (dependencia lineal)?
#
# ---

# %% [markdown]
# Siguiendo el rigor académico de **Clara Mejía Laverde**, avanzamos hacia la contextualización teórica y la aplicación práctica.

# %% [markdown]
# Aquí se establece el "porqué" de la matemática antes de enfrentarnos a los datos.

# %% [markdown]
# ## 6. Introducción
#
# En el estudio del Álgebra Lineal, la **combinación lineal** es la operación fundamental que permite "construir" nuevos elementos a partir de otros preexistentes.

# %% [markdown]
# Si visualizamos los vectores como direcciones de crecimiento o flujos de recursos, la combinación lineal nos indica hasta dónde podemos llegar mediante la suma y la ponderación de estos.

# %% [markdown]
# Para un Ingeniero Agropecuario o un Administrador, esto no es solo teoría de espacios vectoriales; es la base del **modelado predictivo**.

# %% [markdown]
# En la Ciencia de Datos, cuando entrenamos un modelo de *Machine Learning*, estamos buscando los escalares óptimos (pesos) que combinan nuestras variables de entrada para aproximarnos a un resultado real.

# %% [markdown]
# Comprender el **Espacio Generado** ($Span$) es entender el alcance de nuestro modelo: si un problema del mundo real se encuentra fuera del espacio generado por nuestras variables, nuestro modelo jamás podrá resolverlo.

# %% [markdown]
# ## 7. Situaciones Problemáticas
#
# A continuación, se presentan dos escenarios donde los conceptos de este módulo son críticos para la toma de decisiones basada en datos:

# %% [markdown]
# # Situación 1: Ingeniería Agropecuaria (Agricultura de Precisión)
# **Título:** *Balance Nutricional de Precisión para el Cultivo de Cacao.*
# Un ingeniero de suelos cuenta con tres tipos de fertilizantes líquidos comerciales ($F_1, F_2, F_3$), cada uno con concentraciones específicas de Nitrógeno (N), Fósforo (P) y Potasio (K). Un sensor de suelo de última generación indica que un lote específico requiere una dosis exacta de $25$ kg de N, $15$ kg de P y $20$ kg de K para optimizar la cosecha.

# %% [markdown]
# * **Problema:** ¿Existe una **combinación lineal** de los tres fertilizantes que entregue exactamente la dosis requerida? ¿El vector de necesidades del suelo pertenece al **espacio generado** por los fertilizantes disponibles?

# %% [markdown]
# # Situación 2: Administración de Empresas (Optimización Financiera)

# %% [markdown]
# **Título:** *Estructuración de Portafolios de Inversión en Agrotech.*
# Una administradora de empresas desea replicar el comportamiento de un índice de mercado agroindustrial (el "Objetivo") utilizando tres fondos de inversión indexados ($A, B, C$). Cada fondo tiene una exposición porcentual diferente en tres sectores: Bioinsumos, Logística y Exportación.
# * **Problema:** Determinar si el índice objetivo puede ser "generado" por estos tres fondos. Si el conjunto de fondos es un **conjunto generador** para el espacio de riesgo del sector, la administradora podrá cubrir cualquier fluctuación; de lo contrario, existirán riesgos que el portafolio no puede mitigar (están fuera de su $Span$).
#
# ---

# %% [markdown]
# ## 8. Generación de Datasets Artificiales (Python)
#
# Utilizaremos `pandas` para estructurar estos datos, simulando la información que obtendríamos de un repositorio de **GitHub** para un proyecto de Data Science.

# %%
import pandas as pd
import numpy as np

# --- Dataset Situación 1: Fertilizantes (Componentes N, P, K) ---
data_agro = {
    'Componente': ['Nitrógeno (N)', 'Fósforo (P)', 'Potasio (K)'],
    'F1_Vanguardia': [0.2, 0.1, 0.1], # Proporciones por litro
    'F2_Crecimiento': [0.1, 0.3, 0.2],
    'F3_Produccion': [0.1, 0.1, 0.4],
    'Objetivo_Suelo': [25, 15, 20]     # Requerimiento en Kg
}
df_agro = pd.DataFrame(data_agro)
df_agro.head()
# Out:
#       Componente  F1_Vanguardia  F2_Crecimiento  F3_Produccion  Objetivo_Suelo
# 0  Nitrógeno (N)            0.2             0.1            0.1              25
# 1    Fósforo (P)            0.1             0.3            0.1              15
# 2    Potasio (K)            0.1             0.2            0.4              20

# %%
# --- Dataset Situación 2: Portafolios (Sectores de Riesgo) ---
data_admin = {
    'Sector': ['Bioinsumos', 'Logistica', 'Exportacion'],
    'Fondo_A': [0.6, 0.2, 0.2], # Composición del fondo
    'Fondo_B': [0.1, 0.7, 0.2],
    'Fondo_C': [0.3, 0.3, 0.4],
    'Indice_Objetivo': [0.4, 0.3, 0.3] # Perfil a replicar
}
df_admin = pd.DataFrame(data_admin)

print("Dataset Agropecuario:\n", df_agro)
print("\nDataset Administrativo:\n", df_admin)

# %% [markdown]
# Siguiendo con el rigor formal de la propuesta de **Clara Mejía Laverde**, entraremos en la fase de abstracción matemática.

# %% [markdown]
# Aquí es donde los datos de los fertilizantes y los fondos de inversión se transforman en entidades del álgebra lineal.

# %% [markdown]
# ## 9. Definiciones Asociadas al Módulo 3
#
# Utilizaremos el lenguaje **LaTeX** para definir con precisión los conceptos que rigen el comportamiento de nuestros datasets.

# %% [markdown]
# ### A. Combinación Lineal
# Sea $V$ un espacio vectorial sobre un cuerpo $K$ (generalmente $\mathbb{R}$). Un vector $v \in V$ es una **combinación lineal** de los vectores $v_1, v_2, \dots, v_n \in V$ si existen escalares $c_1, c_2, \dots, c_n \in K$ tales que:
#
# $$
# v = c_1v_1 + c_2v_2 + \dots + c_nv_n = \sum_{i=1}^{n} c_iv_i
# $$
#
# En nuestro contexto:
# * $v_i$ son las columnas de nuestros datasets (composición de fertilizantes o fondos).
# * $c_i$ son las cantidades a aplicar o invertir (nuestras variables de decisión).

# %% [markdown]
# ### B. Conjunto Finito Generador
# Se dice que un conjunto de vectores $S = \{v_1, v_2, \dots, v_n\}$ es un **conjunto generador** de un espacio vectorial $V$ si todo vector en $V$ puede escribirse como una combinación lineal de los elementos de $S$. Es decir:
#
# $$V = \left\{ \sum_{i=1}^{n} c_iv_i \mid c_i \in K \right\}$$

# %% [markdown]
# # C. Espacio Generado ($Span$)
# El **espacio generado** por un conjunto de vectores $S$, denotado como $gen(S)$ o $Span(S)$, es el conjunto de todas las combinaciones lineales posibles de los vectores en $S$. Matemáticamente:
#
# $$
# gen\ (v_1, v_2, \dots, v_n) = \{ v \in V : v = c_1v_1 + \dots + c_nv_n \}
# $$
#
# > **Nota para Data Science:** Si nuestro dataset tiene 10 variables, pero 3 de ellas son combinaciones lineales de las otras, el *Span* de nuestros datos tiene una dimensión menor a 10. Esto es la base de la **Reducción de Dimensionalidad**.

# %% [markdown]
# ## 10. Ejemplos de Aplicación
#
# Aterricemos las definiciones anteriores a las situaciones problemáticas del ítem 7.

# %% [markdown]
# ### Ejemplo 1: Aplicación en Ingeniería Agropecuaria
# Para el caso del cultivo de cacao, queremos saber si el requerimiento del suelo $\mathbf{b}$ puede obtenerse combinando los fertilizantes $F_1, F_2$ y $F_3$. Definimos los vectores de concentración:
#
# $$\mathbf{v_1} = \begin{bmatrix} 0.2 \\ 0.1 \\ 0.1 \end{bmatrix}, \quad \mathbf{v_2} = \begin{bmatrix} 0.1 \\ 0.3 \\ 0.2 \end{bmatrix}, \quad \mathbf{v_3} = \begin{bmatrix} 0.1 \\ 0.1 \\ 0.4 \end{bmatrix}$$
#
# El problema se reduce a encontrar los escalares $c_1, c_2, c_3$ (litros de cada fertilizante) tales que:
# $$c_1 \begin{bmatrix} 0.2 \\ 0.1 \\ 0.1 \end{bmatrix} + c_2 \begin{bmatrix} 0.1 \\ 0.3 \\ 0.2 \end{bmatrix} + c_3 \begin{bmatrix} 0.1 \\ 0.1 \\ 0.4 \end{bmatrix} = \begin{bmatrix} 25 \\ 15 \\ 20 \end{bmatrix}$$

# %% [markdown]
# ### Ejemplo 2: Aplicación en Administración de Empresas
# Para la administradora que desea replicar el índice objetivo, el conjunto generador está compuesto por los fondos $A, B$ y $C$. El espacio generado por estos fondos representa todas las posibles combinaciones de riesgo/retorno que ella puede construir.
#
# Si el vector del **Índice Objetivo** $\mathbf{y} = [0.4, 0.3, 0.3]^T$ no pertenece al $Span(A, B, C)$, entonces es matemáticamente imposible replicar exactamente el índice con esos instrumentos financieros, lo que obligaría a la empresa a buscar nuevos activos.
#
# ---

# %% [markdown]
# **¿Continuamos con la Etapa 11 (Teoremas) y la Etapa 12 (Ejemplos de aplicación de teoremas a los datasets)?** Estos teoremas nos dirán, por ejemplo, cuándo un sistema tiene solución única o ninguna.

# %% [markdown]
# Entramos ahora en la fase de **validación y herramientas de decisión**. En álgebra lineal, los teoremas son las reglas que nos permiten saber, sin necesidad de "adivinar", si una solución existe o si nuestros datos son redundantes.
#
# Siguiendo el estilo de Mejía Laverde, presentaremos estos teoremas como pilares de soporte para el análisis de datos.
#
# ---

# %% [markdown]
# ## 11. Teoremas
#
# Para que un ingeniero o administrador pueda confiar en sus modelos, debe conocer estos fundamentos:

# %% [markdown]
# ### Teorema A: Existencia de la Combinación Lineal
# Sea $A$ una matriz cuyas columnas son los vectores $\{v_1, v_2, \dots, v_n\}$ y sea $\mathbf{b}$ un vector de resultados. El vector $\mathbf{b}$ es una combinación lineal de las columnas de $A$ **si y solo si** el sistema de ecuaciones $A\mathbf{x} = \mathbf{b}$ es consistente (tiene al menos una solución).

# %% [markdown]
# ### Teorema B: El Espacio Generado y el Rango
# Sea $S = \{v_1, v_2, \dots, v_n\}$ un conjunto de vectores en $\mathbb{R}^m$. El espacio generado $Span(S)$ es igual a todo $\mathbb{R}^m$ si y solo si el rango de la matriz formada por estos vectores es igual a $m$ ($Rank(A) = m$).
#
# > **Implicación en Data Science:** Si el rango de tu matriz de características (features) es menor al número de variables, tienes **multicolinealidad**. Esto significa que algunas variables son redundantes y podrías simplificar tu modelo sin perder información (Reducción de dimensionalidad).

# %% [markdown]
# ## 12. Aplicación de Teoremas a los Datasets
#
# ### Caso 1: Consistencia en el Cultivo de Cacao
# Utilizando el **Teorema A**, para saber si podemos satisfacer los requerimientos del suelo, construimos la matriz de fertilizantes $A_{agro}$ y verificamos si el vector objetivo $\mathbf{b}$ "vive" en su espacio columna.
#
# En Python, esto se verifica calculando el rango de la matriz de coeficientes y comparándolo con el rango de la matriz aumentada $[A|\mathbf{b}]$. Si son iguales, la combinación lineal existe.

# %% [markdown]
# ### Caso 2: Cobertura del Mercado en Administración
# Utilizando el **Teorema B**, la administradora debe verificar si sus tres fondos ($A, B, C$) generan todo el espacio de riesgo $\mathbb{R}^3$ (Bioinsumos, Logística, Exportación).
# * Si $Rank(A_{admin}) = 3$, ella puede replicar **cualquier** índice objetivo que se le presente.
# * Si $Rank(A_{admin}) < 3$, hay perfiles de riesgo que sus fondos no pueden alcanzar.
#
# ---

# %% [markdown]
# ## 13. Solución a las Situaciones Problemáticas
#
# A continuación, resolvemos matemáticamente ambos casos usando los datos generados en el ítem 8 mediante `numpy`.

# %%
import numpy as np

# --- SOLUCIÓN SITUACIÓN 1 (AGRO) ---
A_agro = np.array([[0.2, 0.1, 0.1],
                   [0.1, 0.3, 0.1],
                   [0.1, 0.2, 0.4]])
b_agro = np.array([25, 15, 20])

# Resolver para c1, c2, c3 (litros de cada fertilizante)
sol_agro = np.linalg.solve(A_agro, b_agro)

print(f"Solución Agropecuaria:")
print(f"Litros F1: {sol_agro[0]:.2f}, F2: {sol_agro[1]:.2f}, F3: {sol_agro[2]:.2f}")

# --- SOLUCIÓN SITUACIÓN 2 (ADMIN) ---
A_admin = np.array([[0.6, 0.1, 0.3],
                    [0.2, 0.7, 0.3],
                    [0.2, 0.2, 0.4]])
b_admin = np.array([0.4, 0.3, 0.3])

# Resolver para determinar pesos de inversión
sol_admin = np.linalg.solve(A_admin, b_admin)

print(f"\nSolución Administrativa (Pesos del Portafolio):")
print(f"Inversión Fondo A: {sol_admin[0]*100:.1f}%")
print(f"Inversión Fondo B: {sol_admin[1]*100:.1f}%")
print(f"Inversión Fondo C: {sol_admin[2]*100:.1f}%")
# Out:
# Solución Agropecuaria:
# Litros F1: 112.50, F2: 6.25, F3: 18.75
#
# Solución Administrativa (Pesos del Portafolio):
# Inversión Fondo A: 40.0%
# Inversión Fondo B: 10.0%
# Inversión Fondo C: 50.0%

# %% [markdown]
# **Resultado del análisis:**
# 1. **Agro:** Existe una combinación única. Se requieren cantidades específicas de cada producto para no desperdiciar nutrientes ni dejar el suelo pobre.
# 2. **Admin:** El índice objetivo se logra invirtiendo proporciones exactas de cada fondo, demostrando que el índice objetivo pertenece al espacio generado por los activos disponibles.
#
# ---

# %% [markdown]
# Para cerrar este tercer módulo con el rigor y la visión de **Clara Mejía Laverde**, presentamos la fase de consolidación del aprendizaje (ejercicios) y el sustento epistemológico de la propuesta.
#
# ---

# %% [markdown]
# # 14. Ejercicios Sugeridos
#
# Para estos ejercicios, deberás aplicar los scripts de Python desarrollados en las etapas anteriores.

# %% [markdown]
# # Ejercicio A: Diagnóstico de Redundancia en Sensores (Agropecuaria)
# En una red de sensores de humedad de precisión, se tienen tres dispositivos ($S_1, S_2, S_3$) que miden tres variables ambientales. Los vectores de lectura son:
# * $S_1 = [1, 2, 1]^T$
# * $S_2 = [2, 4, 2]^T$
# * $S_3 = [1, 0, 3]^T$
#
# 1. **Reto:** Determina si el conjunto $\{S_1, S_2, S_3\}$ es un **conjunto generador** de $\mathbb{R}^3$.
# 2. **Contexto Data Science:** Si intentas entrenar un modelo de Deep Learning con estos tres sensores, ¿hay alguno que no esté aportando información nueva (es decir, es una combinación lineal de los otros)?
# 3. **Pista:** Calcula el determinante o el rango en Python.

# %% [markdown]
# ### Ejercicio B: Mezcla de Alimento Balanceado (Administración/Producción)
# Una planta procesadora busca crear una dieta para ganado con: 40% Proteína, 30% Grasa y 30% Fibra. Dispone de tres insumos con las siguientes composiciones:
# * **Insumo 1 (Maíz):** [10%, 5%, 85%]
# * **Insumo 2 (Soja):** [45%, 20%, 35%]
# * **Insumo 3 (Harina de pescado):** [60%, 25%, 15%]
#
# 1. **Reto:** Escribe el vector objetivo $\mathbf{b}$ y la matriz $A$.
# 2. **Cálculo:** Encuentra los escalares (cantidades de cada insumo) necesarios. Si alguno da negativo, ¿qué significa esto para el **espacio generado** y la realidad física del problema?
#
# ---

# %% [markdown]
# ## 15. Referentes Didácticos y del Álgebra Lineal
#
# Esta propuesta de enseñanza no es arbitraria; se fundamenta en corrientes pedagógicas y autores clásicos que validan la integración de la computación con la abstracción:

# %% [markdown]
# ### Referentes de Álgebra Lineal
# * **Strang, G. (2016). *Introduction to Linear Algebra*:** Su enfoque en el "espacio columna" de una matriz es la base para entender el **Span** en ciencia de datos.
# * **Lay, D. (2012). *Linear Algebra and its Applications*:** Proporciona la estructura lógica para conectar sistemas de ecuaciones con combinaciones lineales, esencial para la ingeniería.

# %% [markdown]
# # Referentes Didácticos

# %% [markdown]
# * **Clara Mejía Laverde:** De quien tomamos la estructura de **situación-problema**. Mejía propone que el aprendizaje de la matemática en ingeniería debe ser significativo, partiendo de contextos reales para llegar a la formalización (Modelo de Educación por Competencias).

# %% [markdown]
# * **Papert, S. (Construccionismo):** El uso de **Python** como "objeto para pensar". Al programar la solución, el estudiante construye el concepto de combinación lineal de forma tangible.

# %% [markdown]
# * **Enfoque STEM/Data Science:** La integración de GitHub y YouTube emula los entornos de colaboración profesional modernos, preparando al estudiante para la **Ciencia de Datos** aplicada.

# %% [markdown]
# > **Conclusión del Módulo:** Hemos pasado de ver los datos como simples listas a entenderlos como **vectores** que habitan en espacios. En el próximo módulo, daremos el siguiente paso: entender cuándo estos vectores son verdaderamente "independientes" y cómo forman la **Base** de todo sistema de inteligencia artificial.

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Cursos que orienta el profesor Marco Julio Cañas Campillo en 2025
#
# 1. Lunes 8 a 12: Asesoría Trabajo de Grado Janis (Estudiante de Biología).
# 2. Lunes 2 a 5 PM:
# 3. Lunes 5 a 8 PM: PIVU Caucasia.
# 4. Martes de 9 a 11:
# 5. Martes de 2 a 6 PM: Álgebra Lineal.
# 6. Martes de 6 a 8 PM: PIVU Caucasia.
# 7. Miércoles: 2 a 3 PM:
# 8. Miércoles de 5 a 8 PM PIVU Caucasia.
# 9. Jueves 8 AM a 12 M: Fundamentos de Programación.
# 10. Jueves 2 a 5 PM:
# 11. Jueves de 5 a 8 PM: PIVU Caucasia
# 12. Viernes 8 a 12: Asesorías a los cursos de Álgebra Lineal y Fundamentos de Programación.
# 13. Viernes de 2 PM - 3PM: Reunión con el equipo investigador SAT Dengue.
# 14. Viernes 2 a 6 PM:
# 15. Sábados de 5 AM a 6 PM: PIVU Puerto Libertador.

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Álgebra Lineal de Clara Elena Mejía Laverde](https://www.academia.edu/43065939/Alg_Lineal_Clara_Mejia_Universidad_de_Ant)

# %% [markdown]
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html

# %% [markdown]
# * Wing, J. M. (2006). Computational thinking. Communications of the ACM, 49(3), 33-35. https://doi.org/10.1145/1118178.1118215

# %% [markdown]
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)

# %% [markdown]
# * [chatGPT](https://openai.com/blog/chatgpt)

# %% [markdown]
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.

# %% [markdown]
# # Estado del arte con citas

# %% [markdown]
# El uso de la tecnología en la enseñanza de las matemáticas encuentra uno de sus pilares en **Papert (1980)**, quien afirmaba que *“los niños no aprenden sobre la computadora, aprenden con la computadora”* (p. 6).

# %% [markdown]
# En su visión, la programación se convierte en un medio para la construcción activa de significados matemáticos, idea que se enlaza con la epistemología genética de **Piaget (1970)**, quien sostuvo que *“el conocimiento se construye a través de la acción”* (p. 15), y con la perspectiva de **Vygotsky (1978)**, al señalar que *“toda función en el desarrollo cultural del niño aparece dos veces: primero en el plano social y después en el individual”* (p. 57).

# %% [markdown]
# Estos enfoques coinciden en otorgar a las herramientas culturales un papel esencial en la mediación del aprendizaje.

# %% [markdown]
# Posteriormente, **Wing (2006)** acuñó el término pensamiento computacional, definiéndolo como *“una habilidad fundamental para todos, no solo para los científicos de la computación”* (p. 33).

# %% [markdown]
# Esta autora subrayó que debía enseñarse de manera transversal, en paralelo con la lectura, la escritura y la matemática.

# %% [markdown]
# En la misma línea, el **NCTM (2000)** destacó que *“la tecnología es esencial en la enseñanza y el aprendizaje de las matemáticas; influye en la matemática que se enseña y mejora el aprendizaje de los estudiantes”* (p. 24).

# %% [markdown]
# Desde la didáctica de las matemáticas, **Duval (2006)** mostró que *“la comprensión matemática requiere la coordinación de al menos dos registros de representación diferentes”* (p. 107), lo que legitima la incorporación de registros digitales como LaTeX, Markdown y Python.

# %% [markdown]
# Por su parte, **Godino (2017)** planteó que *“el significado de un objeto matemático está constituido por el sistema de prácticas en el que interviene”* (p. 7), con lo cual la práctica digital se convierte en parte constitutiva del aprendizaje matemático.

# %% [markdown]
# Finalmente, organismos internacionales como la **ACM y el IEEE (2013)** enfatizan que *“las habilidades computacionales son esenciales para el ejercicio profesional en cualquier disciplina”* (p. 12).

# %% [markdown]
# De esta manera, se consolida un consenso: la enseñanza universitaria de las matemáticas debe integrar herramientas contemporáneas como **Jupyter Notebooks, Python, LaTeX, Markdown e inglés**, no para competir con la enseñanza tradicional, sino para **fortalecer la comprensión matemática, potenciar la comunicación científica y responder a las demandas del mundo laboral**.
#
# ---

# %% [markdown]
# Con este estado del arte tengo **citas directas y cortas** que le dan más fuerza académica a tu postura.

# %% [markdown]
# # Estructura de cada Módulo (Total de módulos: 22)
#
# 1. Título
# 2. Imagen introductoria generado con Plotly
# 3. Contenido
# 4. Objetivos de aprendizaje
# 5. Preguntas Orientadoras
# 6. Introducción
# 7. Dos situaciones problemáticas asociadas a ciencia de datos agropecuarios o de Administración de empresas y al tema del módulo en particular (Para el módulo 4: debes dar una situación donde se aplique el tema de dependencia e independencia lineal del Álgebra Lineal). Por ejemplo, datos asociados a mediciones en agricultura de precisión.
# 8. Genere, de manera artificial, los dos datasets asociados la situción problemática anterior.
# 9.  Definiciones asociadas al módulo respectivo (Para este cuaderno el módulo 4: debes dar las definiciones en lenguaje Látex asociadas al tema de dependencia e independencia lineal del Álgebra Lineal)
# 10. Ejemplos: (Genere ejemplos de aplicación de estos conceptos de este módulo a las dos situaciones anteriores)
# 11. Teoremas: (Genere los teoremas del álgebra lineal que facilitan el uso de los temas del módulo para la solución de la situación problemática.)
# 12. Ejemplos: (Genere ejemplos de aplicación de los teoremas para los datasets de las situaciones problemáticas del módulo)
# 13. Ejercicios (Genere ejercicios sugeridos con dataset artificiales nuevos)
