# %% [markdown]
# Este es el **diseño del Quinto Parcial (Final)**, coherente con toda la arquitectura del curso, **integrador**, con **4 puntos evaluables**, y centrado en el **Capítulo 5**.
#
# ---
#
# # Diseño del Quinto Parcial (Final) – Álgebra Lineal
#
# **Programa:** Ingeniería Agropecuaria – UdeA Campus Caucasia
# **Parcial:** 5 (Final)
# **Fecha:** martes **12 de mayo**
# **Duración:** 2 horas
# **Modalidad:** Individual, escrita
# **Ponderación sugerida:** 20 % del curso
#
# ---
#
# ## Unidades evaluadas
#
# **Capítulo 5 – Diagonalización ortogonal, formas cuadráticas y aproximación espectral**
#
# * Diagonalización ortogonal
# * Formas cuadráticas
# * Secciones cónicas (enfoque conceptual)
# * Aproximación de valores y vectores característicos
#
# ---
#
# ## Objetivo del parcial
#
# Evaluar la capacidad del estudiante para **analizar matrices simétricas**, interpretar **formas cuadráticas**, comprender la **aproximación espectral**, y **conectar estos conceptos con optimización, estadística y machine learning** aplicados a la ingeniería agropecuaria.
#
# ---
#
# ## Competencias evaluadas
#
# * Aplica la diagonalización ortogonal
# * Analiza e interpreta formas cuadráticas
# * Clasifica cónicas mediante álgebra lineal
# * Comprende métodos de aproximación espectral
# * Relaciona estos conceptos con optimización y deep learning
#
# ---
#
# ## 📊 Estructura del parcial (4 puntos)
#
# | Punto     | Tipo                    | Contenidos                     | %         |
# | --------- | ----------------------- | ------------------------------ | --------- |
# | 1         | Analítico–procedimental | Diagonalización ortogonal      | 25 %      |
# | 2         | Conceptual–geométrico   | Formas cuadráticas y cónicas   | 25 %      |
# | 3         | Analítico               | Aproximación espectral         | 25 %      |
# | 4         | Integrador–aplicado     | Ciencia de datos agropecuarios | 25 %      |
# | **Total** |                         |                                | **100 %** |
#
# ---
#
# ## ✍️ Desarrollo sugerido del parcial
#
# ---
#
# ### **Punto 1 – Diagonalización ortogonal (25 %)**
#
# Sea una matriz simétrica que representa la matriz de covarianza de un conjunto de datos agrícolas.
#
# a) Justifique por qué la matriz es diagonalizable ortogonalmente.
# b) Determine una base ortonormal de vectores característicos.
# c) Construya la matriz diagonal asociada.
#
# 🔎 *Se evalúa:* dominio del teorema espectral y cálculo correcto.
#
# ---
#
# ### **Punto 2 – Formas cuadráticas y secciones cónicas (25 %)**
#
# Considere una forma cuadrática asociada a una función de costo en un problema de optimización agrícola.
#
# a) Exprese la forma cuadrática en términos matriciales.
# b) Determine su clasificación mediante cambio ortogonal de variables.
# c) Interprete el tipo de cónica obtenida en el contexto del problema.
#
# 🔎 *Se evalúa:* interpretación algebraico–geométrica.
#
# ---
#
# ### **Punto 3 – Aproximación de valores y vectores característicos (25 %)**
#
# En matrices de gran tamaño, el cálculo exacto de valores característicos no siempre es viable.
#
# a) Explique la idea básica de un método de aproximación de valores propios.
# b) Describa el significado del vector característico dominante.
# c) Relacione este concepto con procesos iterativos usados en ciencia de datos.
#
# 🔎 *Se evalúa:* comprensión teórica y lectura computacional.
#
# ---
#
# ### **Punto 4 – Aplicación integradora a ciencia de datos (25 %)**
#
# En modelos de machine learning aplicados a la ingeniería agropecuaria:
#
# a) Explique el papel de la diagonalización ortogonal en PCA.
# b) Relacione formas cuadráticas con funciones de pérdida.
# c) Conecte la aproximación espectral con algoritmos de deep learning.
#
# 🔎 *Se evalúa:* integración total del curso.
#
# ---
#
# ## 🧪 Criterios de evaluación
#
# * Rigor matemático y claridad conceptual
# * Correcta ejecución de procedimientos
# * Capacidad de interpretación aplicada
# * Articulación coherente entre álgebra lineal y ciencia de datos
#
# ---
#
# ## 📌 Observación pedagógica final
#
# Este parcial **cierra el curso** mostrando al estudiante que el álgebra lineal:
#
# * no es solo cálculo simbólico,
# * sino **lenguaje estructural de la ciencia de datos, el machine learning y el deep learning** en ingeniería agropecuaria.
