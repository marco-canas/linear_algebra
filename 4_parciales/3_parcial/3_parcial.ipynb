# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/vector_geometry_and_linear_algebra/blob/main/2_planificacion/1_formatos_clase/vector_geometry_and_linear_algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/vector_geometry_and_linear_algebra/blob/main/2_planificacion/1_formatos_clase/vector_geometry_and_linear_algebra.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# [Video de apoyo a la preparación de este parcial]()

# %% [markdown]
# # Diseño del Tercer Parcial – Álgebra Lineal
#
# **Programa:** Ingeniería Agropecuaria – UdeA Campus Caucasia
# **Parcial:** 3
# **Fecha:** martes **28 de abril**
# **Duración:** 2 horas
# **Modalidad:** Individual, escrita
# **Ponderación sugerida:** 20 % del curso
#
# ---

# %% [markdown]
# ## 📚 Unidades evaluadas
#
# **Cierre del Capítulo 3 e inicio del Capítulo 4**
#
# ### Capítulo 3 – Transformaciones Lineales
#
# * Representación matricial de transformaciones lineales
# * Isomorfismos (transformaciones lineales invertibles)
# * Isometrías
#
# ### Capítulo 4 – Valores y vectores característicos
#
# * Definición y propiedades
# * Primer acercamiento a la diagonalización
#
# ---
#
# ## 🎯 Objetivo del parcial
#
# Evaluar la capacidad del estudiante para **representar y analizar transformaciones lineales mediante matrices**, identificar **transformaciones invertibles y preservadoras de distancias**, e **introducir el análisis espectral** como herramienta clave en modelado y análisis de datos agropecuarios.
#
# ---

# %% [markdown]
# ## 🧠 Competencias evaluadas
#
# * Construye la matriz asociada a una transformación lineal
# * Determina invertibilidad e isomorfismos
# * Analiza isometrías y preservación geométrica
# * Calcula e interpreta valores y vectores característicos
# * Relaciona estos conceptos con PCA y modelos dinámicos
#
# ---

# %% [markdown]
# ## 📊 Estructura del parcial (4 puntos)
#
# | Punto     | Tipo                      | Contenidos                         | %         |
# | --------- | ------------------------- | ---------------------------------- | --------- |
# | 1         | Procedimental–estructural | Representación matricial           | 25 %      |
# | 2         | Conceptual–geométrico     | Isomorfismos e isometrías          | 25 %      |
# | 3         | Analítico                 | Valores y vectores característicos | 25 %      |
# | 4         | Aplicado                  | Ciencia de datos agropecuarios     | 25 %      |
# | **Total** |                           |                                    | **100 %** |
#
# ---
#
# ## ✍️ Desarrollo sugerido del parcial
#
# ---
#
# ### **Punto 1 – Representación matricial (25 %)**
#
# Sea (T: \mathbb{R}^3 \to \mathbb{R}^3) una transformación lineal que modela un proceso de normalización de variables agrícolas.
#
# a) Determine la matriz asociada a (T) respecto a la base canónica.
# b) Calcule (T(\mathbf{x})) para un vector de datos dado.
# c) Explique la ventaja de representar transformaciones mediante matrices en el análisis de datos.
#
# 🔎 *Se evalúa:* dominio algebraico y lectura matricial.
#
# ---
#
# ### **Punto 2 – Isomorfismos e isometrías (25 %)**
#
# Considere una transformación lineal que preserva distancias entre vectores de mediciones agrícolas.
#
# a) Defina qué significa que una transformación sea un isomorfismo.
# b) Verifique si la transformación dada es invertible.
# c) Determine si es una isometría y justifique su respuesta.
#
# 🔎 *Se evalúa:* comprensión estructural y razonamiento geométrico.
#
# ---
#
# ### **Punto 3 – Valores y vectores característicos (25 %)**
#
# Sea una matriz que representa la interacción entre variables agroambientales.
#
# a) Calcule los valores característicos.
# b) Determine los vectores característicos asociados.
# c) Interprete el significado de un valor característico dominante en el sistema modelado.
#
# 🔎 *Se evalúa:* cálculo, análisis espectral e interpretación.
#
# ---
#
# ### **Punto 4 – Aplicación a ciencia de datos (25 %)**
#
# En el análisis de datos agrícolas multivariados:
#
# a) Explique la relación entre valores característicos y direcciones principales de variabilidad.
# b) Describa cómo estos conceptos se utilizan en el Análisis de Componentes Principales (PCA).
# c) Relacione el uso de valores propios con la reducción de dimensionalidad en Python.
#
# 🔎 *Se evalúa:* integración teoría–aplicación–pensamiento computacional.
#
# ---
#
# ## 🧪 Criterios de evaluación
#
# * Corrección algebraica y rigor lógico
# * Uso adecuado del lenguaje matemático
# * Interpretación geométrica y aplicada
# * Capacidad de conexión con ciencia de datos agropecuarios
#
# ---
#
# ## 📌 Observación pedagógica
#
# Este parcial marca el **punto de inflexión del curso**: los estudiantes pasan del estudio estructural de transformaciones al **análisis espectral**, base matemática del **PCA, modelos dinámicos y deep learning**.
#
# ---

# %% [markdown]
# ¡Vamos con el **Parcial 3**, Marco! 📐🌾
# Mantengo **exactamente la misma lógica de diseño** de los parciales 1 y 2: rigor matemático + lectura estructural + aplicación a **ingeniería agropecuaria y ciencia de datos con Python**, y **4 puntos evaluables** bien balanceados.
#
# ---
#
# # 📝 Diseño del Tercer Parcial – Álgebra Lineal
#
# **Programa:** Ingeniería Agropecuaria – UdeA Campus Caucasia
# **Parcial:** 3
# **Fecha:** martes **28 de abril**
# **Duración:** 2 horas
# **Modalidad:** Individual, escrita
# **Ponderación sugerida:** 20 % del curso
#
# ---
#
# ## 📚 Unidades evaluadas
#
# **Cierre del Capítulo 3 e inicio del Capítulo 4**
#
# ### Capítulo 3 – Transformaciones Lineales
#
# * Representación matricial de transformaciones lineales
# * Isomorfismos (transformaciones lineales invertibles)
# * Isometrías
#
# ### Capítulo 4 – Valores y vectores característicos
#
# * Definición y propiedades
# * Primer acercamiento a la diagonalización
#
# ---
#
# ## 🎯 Objetivo del parcial
#
# Evaluar la capacidad del estudiante para **representar y analizar transformaciones lineales mediante matrices**, identificar **transformaciones invertibles y preservadoras de distancias**, e **introducir el análisis espectral** como herramienta clave en modelado y análisis de datos agropecuarios.
#
# ---
#
# ## 🧠 Competencias evaluadas
#
# * Construye la matriz asociada a una transformación lineal
# * Determina invertibilidad e isomorfismos
# * Analiza isometrías y preservación geométrica
# * Calcula e interpreta valores y vectores característicos
# * Relaciona estos conceptos con PCA y modelos dinámicos
#
# ---
#
# ## 📊 Estructura del parcial (4 puntos)
#
# | Punto     | Tipo                      | Contenidos                         | %         |
# | --------- | ------------------------- | ---------------------------------- | --------- |
# | 1         | Procedimental–estructural | Representación matricial           | 25 %      |
# | 2         | Conceptual–geométrico     | Isomorfismos e isometrías          | 25 %      |
# | 3         | Analítico                 | Valores y vectores característicos | 25 %      |
# | 4         | Aplicado                  | Ciencia de datos agropecuarios     | 25 %      |
# | **Total** |                           |                                    | **100 %** |
#
# ---
#
# ## ✍️ Desarrollo sugerido del parcial
#
# ---
#
# ### **Punto 1 – Representación matricial (25 %)**
#
# Sea (T: \mathbb{R}^3 \to \mathbb{R}^3) una transformación lineal que modela un proceso de normalización de variables agrícolas.
#
# a) Determine la matriz asociada a (T) respecto a la base canónica.
# b) Calcule (T(\mathbf{x})) para un vector de datos dado.
# c) Explique la ventaja de representar transformaciones mediante matrices en el análisis de datos.
#
# 🔎 *Se evalúa:* dominio algebraico y lectura matricial.
#
# ---
#
# ### **Punto 2 – Isomorfismos e isometrías (25 %)**
#
# Considere una transformación lineal que preserva distancias entre vectores de mediciones agrícolas.
#
# a) Defina qué significa que una transformación sea un isomorfismo.
# b) Verifique si la transformación dada es invertible.
# c) Determine si es una isometría y justifique su respuesta.
#
# 🔎 *Se evalúa:* comprensión estructural y razonamiento geométrico.
#
# ---
#
# ### **Punto 3 – Valores y vectores característicos (25 %)**
#
# Sea una matriz que representa la interacción entre variables agroambientales.
#
# a) Calcule los valores característicos.
# b) Determine los vectores característicos asociados.
# c) Interprete el significado de un valor característico dominante en el sistema modelado.
#
# 🔎 *Se evalúa:* cálculo, análisis espectral e interpretación.
#
# ---
#
# ### **Punto 4 – Aplicación a ciencia de datos (25 %)**
#
# En el análisis de datos agrícolas multivariados:
#
# a) Explique la relación entre valores característicos y direcciones principales de variabilidad.
# b) Describa cómo estos conceptos se utilizan en el Análisis de Componentes Principales (PCA).
# c) Relacione el uso de valores propios con la reducción de dimensionalidad en Python.
#
# 🔎 *Se evalúa:* integración teoría–aplicación–pensamiento computacional.
#
# ---
#
# ## 🧪 Criterios de evaluación
#
# * Corrección algebraica y rigor lógico
# * Uso adecuado del lenguaje matemático
# * Interpretación geométrica y aplicada
# * Capacidad de conexión con ciencia de datos agropecuarios
#
# ---
#
# ## 📌 Observación pedagógica
#
# Este parcial marca el **punto de inflexión del curso**: los estudiantes pasan del estudio estructural de transformaciones al **análisis espectral**, base matemática del **PCA, modelos dinámicos y deep learning**.
#
# ---
