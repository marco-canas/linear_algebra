# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/vector_geometry_and_linear_algebra/blob/main/2_planificacion/1_formatos_clase/vector_geometry_and_linear_algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/vector_geometry_and_linear_algebra/blob/main/2_planificacion/1_formatos_clase/vector_geometry_and_linear_algebra.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# # [Video de apoyo a la preparación de este parcial]()

# %% [markdown]
# # Diseño del Cuarto Parcial – Álgebra Lineal
#
# **Programa:** Ingeniería Agropecuaria – UdeA Campus Caucasia
# **Parcial:** 4
# **Fecha:** martes **12 de mayo**
# **Duración:** 2 horas
# **Modalidad:** Individual, escrita
# **Ponderación sugerida:** 20 % del curso
#
# ---

# %% [markdown]
# ## 📚 Unidades evaluadas
#
# **Cierre del Capítulo 4 y parte inicial del Capítulo 5**
#
# ### Capítulo 4 – Valores y vectores característicos
#
# * Diagonalización de matrices
# * Aplicaciones de la diagonalización
# * Formas canónicas de Jordan
#
# ### Capítulo 5 – Diagonalización ortogonal
#
# * Introducción a matrices simétricas
# * Interpretación geométrica de la diagonalización
#
# ---
#
# ## 🎯 Objetivo del parcial
#
# Evaluar la capacidad del estudiante para **analizar matrices mediante diagonalización**, reconocer cuándo este proceso es posible, interpretar **formas canónicas** y **conectar el análisis espectral con modelos agrícolas, optimización y ciencia de datos**.
#
# ---
#
# ## 🧠 Competencias evaluadas
#
# * Determina si una matriz es diagonalizable
# * Ejecuta procesos de diagonalización
# * Analiza formas canónicas de Jordan
# * Comprende la diagonalización ortogonal
# * Relaciona estos conceptos con PCA, modelos dinámicos y optimización
#
# ---
#
# ## 📊 Estructura del parcial (4 puntos)
#
# | Punto     | Tipo                    | Contenidos               | %         |
# | --------- | ----------------------- | ------------------------ | --------- |
# | 1         | Analítico–procedimental | Diagonalización          | 25 %      |
# | 2         | Estructural             | Aplicaciones y dinámica  | 25 %      |
# | 3         | Conceptual              | Forma canónica de Jordan | 25 %      |
# | 4         | Aplicado                | Ciencia de datos y PCA   | 25 %      |
# | **Total** |                         |                          | **100 %** |
#
# ---
#
# ## ✍️ Desarrollo sugerido del parcial
#
# ---
#
# ### **Punto 1 – Diagonalización de matrices (25 %)**
#
# Sea una matriz que modela interacciones entre variables agrícolas.
#
# a) Determine sus valores y vectores característicos.
# b) Establezca si la matriz es diagonalizable.
# c) En caso afirmativo, construya la matriz diagonal y la matriz de cambio de base correspondiente.
#
# 🔎 *Se evalúa:* cálculo correcto y comprensión del proceso.
#
# ---
#
# ### **Punto 2 – Aplicaciones de la diagonalización (25 %)**
#
# Considere un sistema dinámico discreto que modela la evolución de una plaga agrícola.
#
# a) Exprese el sistema en forma matricial.
# b) Explique cómo la diagonalización permite analizar el comportamiento a largo plazo del sistema.
# c) Interprete el significado agronómico de los valores característicos.
#
# 🔎 *Se evalúa:* modelación y lectura dinámica.
#
# ---
#
# ### **Punto 3 – Forma canónica de Jordan (25 %)**
#
# Sea una matriz no diagonalizable.
#
# a) Explique por qué no es diagonalizable.
# b) Determine su forma canónica de Jordan.
# c) Justifique la utilidad teórica de la forma de Jordan en el análisis de sistemas.
#
# 🔎 *Se evalúa:* comprensión estructural profunda.
#
# ---
#
# ### **Punto 4 – Aplicación a ciencia de datos (25 %)**
#
# En el análisis multivariado de datos agrícolas:
#
# a) Explique la diferencia entre diagonalización general y diagonalización ortogonal.
# b) Describa por qué las matrices de covarianza son simétricas.
# c) Relacione estos conceptos con el uso de PCA en Python (`numpy`, `scikit-learn`).
#
# 🔎 *Se evalúa:* integración matemática–computacional.
#
# ---
#
# ## 🧪 Criterios de evaluación
#
# * Rigor algebraico y claridad en los procedimientos
# * Uso correcto del lenguaje matemático
# * Capacidad de interpretación aplicada
# * Conexión efectiva con ciencia de datos agropecuarios
#
# ---
#
# ## 📌 Observación pedagógica
#
# Este parcial consolida la **madurez matemática del curso**, preparando al estudiante para comprender:
#
# * PCA,
# * análisis espectral,
# * estabilidad de sistemas,
# * y fundamentos algebraicos del deep learning.
#
# ---
